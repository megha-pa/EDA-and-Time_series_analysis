# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
df_tesla=pdr.get_data_yahoo("TSLA")
df_
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-03-02   50.655998   49.653999   49.942001   50.096001  16759000.0
# 2017-03-03   50.380001   49.799999   50.147999   50.313999  14597000.0
# 2017-03-06   50.340000   49.501999   49.582001   50.242001  16777500.0
# 2017-03-07   50.778000   49.664001   50.383999   49.717999  17297500.0
# 2017-03-08   50.014000   49.063999   49.400002   49.374001  18626000.0
# ...                ...         ...         ...         ...         ...
# 2022-02-23  835.299988  760.559998  830.429993  764.039978  31752300.0
# 2022-02-24  802.479980  700.000000  700.390015  800.770020  45107400.0
# 2022-02-25  819.500000  782.400024  809.229980  809.869995  25355900.0
# 2022-02-28  876.859985  814.710022  815.010010  870.429993  33002300.0
# 2022-03-01  889.880005  853.780029  869.679993  864.369995  24840000.0
#
#              Adj Close
# Date
# 2017-03-02   50.096001
# 2017-03-03   50.313999
# 2017-03-06   50.242001
# 2017-03-07   49.717999
# 2017-03-08   49.374001
# ...                ...
# 2022-02-23  764.039978
# 2022-02-24  800.770020
# 2022-02-25  809.869995
# 2022-02-28  870.429993
# 2022-03-01  864.369995
#
# [1259 rows x 6 columns]

# %% [markdown]
# # simple moving average

# %% [raw]
# example-when window size =5
# open simple moving average
# 12
# 13
# 15
# 17
# 11  (12+13+15+17+11)/5=16
# 12  (13+15+17+11+12)/5=13.6
# 5   (15+17+11+12+5)/5=12

# %%
df_tesla["Open"].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#min period parameter in rolling forecast means the how many starting points for rolling widow willbe nan
df_tesla['open_10day']=df_tesla['Open'].rolling(window=10,min_periods=1).mean()

# %%
df_tesla[['open_10day','Open']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['open_20day']=df_tesla['Open'].rolling(window=20,min_periods=1).mean()
df_tesla['open_30day']=df_tesla['Open'].rolling(window=30,min_periods=1).mean()
df_tesla['open_40day']=df_tesla['Open'].rolling(window=40,min_periods=1).mean()

# %%
df_tesla[['open_10day','Open','open_20day','open_30day','open_40day']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Disadvantage of simple MA-
# 1.giving similar importance to all data (x1+x2+x3)/n in time series we want to give more importance to recent data

# %%
##expanding

df_tesla["Open"].expanding().mean().plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # cumulative MA

# %% [raw]
# # Cumilative MA-
# open
# 12
# 13    (12+13)/2=12.5
# 11    (12+13+11)/3=12
# 15    (12+13+11+15)=12.5

# %% [markdown]
# # Exponential MA

# %% [raw]
# we need to focus on recent data
# multiplier=2/(windowsize+1)
# prev ema=average of all previous data (windows size points average)
# EMA formula=((open-prev ema)*multiplier)+Prev EMA

# %%
df_tesla['EMA_0.1']=df_tesla['Open'].ewm(alpha=0.1,adjust=False).mean()##alpha is the smoothening factor

# %%
df_tesla[['open_10day','EMA_0.1']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
EWMA

# %%
df_tesla['EMA_5days']=df_tesla['Open'].ewm(span=5).mean()##to give multiplier effect make it as EWMA

# %%
df_tesla[['open_10day','EMA_5days']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # ARIMA

# %% [raw]
# ARIMA- AR   I     MA
#      Auto regression + Moving Average
#
# MA predicted=mue+q1et-1
# consider initial-MA=10 and q1=0.5
# t     predicted       et-1  actual
# 1          10           -2  8
# 2           9            1  10   predicted=10+0.5*-2=9
# 3           9.5        -1  8.5                 =9+0.5*1=9.5
# 4           10           2   12                =10.5*0.5*-1=10
# 5            11          0   11                 =10*0.5*2=11
